# %% [markdown]
# # Model akomodacji LDL'a przy wykorzystaniu metody stochastycznej.

# %% [markdown]
# Wstęp
# -----
#
#
# W tym dokumencie opisany jest sposób modelowania transportu LDL w ścianie naczynia. Program rozwiązuje problem transportu zgodnie z równaniem:
#
# \begin{eqnarray}
#       \frac{\partial c}{\partial t} +(1-\sigma)\vec u\cdot\nabla c & = & D_{eff} \nabla^2 c - k c
# \end{eqnarray}
#
# Przyjmując jednowymiarowy model, w kierunku radialnym, prędkość  filtracji $\vec u$ ta musi być stała na całym odcinku filtracji przez ścianę.
# Poniższe symulacje przyjmują wartość $v=2.3\cdot 10^{-5} \frac{mm}{s}=0.023 \frac{\mu m}{s}.$ Jednak w  efektywna prędkość
# unoszenia jest dana wzrorem $(1-\sigma)\vec u$, gdzie $\sigma$ to współczynnik odbicia. Oznacza to, że w zależności od efektywnych własności materiału
# w którym poruszają się cząsteczki LDL mamy różne prędkości dryftu.
#
# Symulacja wykorzystuje metodę stochastyczną.

# %%
import numpy as np 
from scipy.sparse import dia_matrix
import scipy as sp
import scipy.sparse
import scipy.sparse.linalg
import matplotlib.pyplot as pl
import pycuda.gpuarray as gpuarray
from pycuda.curandom import rand as curand

from pycuda.compiler import SourceModule
import pycuda.driver as cuda

# %% [markdown]
# Parametry:

# %%
nazwy       = [  'container','endothel' , 'intima']
#dobre
D           =[   6e-11     ,  6e-11  , 5.4e-6 , 3.18e-9  ,  5e-8] 
V           = [   2.6783499775030101e-5    ,  2.6783499775030101e-5    , 2.6783499775030101e-5  , 2.6783499775030101e-5, 2.6783499775030101e-5 ]
sigma       = [  0.93108378484950194,     0.93108378484950194, 0.8272, 0.9827, 0.8836]
L           = [    0.2      ,  1.8        ,10. ,2.0, 200.]
k_react     = [    0.       ,  0.        , 0. , 0., 1.4e-4]

#nazwy       = [  'container','endothel' , 'intima', 'IEL'   ,'media']
#D           =[   6e-9     ,  6e-9  , 5.4e-6 , 3.18e-9  ,  5e-8] #[   6e-11     ,  6e-11  , 5.4e-6  , 3.18e-9  ]
#V           = [   2.6783499775030101e-5    ,  2.6783499775030101e-5    , 2.6783499775030101e-5  , 2.6783499775030101e-5, 2.6783499775030101e-5 ]#, 2.6783499775030101e-5  
#sigma       = [  0.93108378484950194,     0.93108378484950194, 0.8272, 0.9827, 0.8836]#, 0.9827]#0.9827, 0.8836] 
#L           = [    0.2      ,  1.8        ,10. ,1.,0.]#2.0, 200.]#,5.    ]#,    2.   , 200.   ]#test rozmiaru kontenera
#k_react     = [    0.       ,  0.        , 0. , 0., 0.]#1.4e-4]

K           = [   3.32e-15  , 2e-10   ,4.392e-13, 2e-12   ]
mu          = [   0.72e-3   , 0.72e-3 , 0.72e-3 , 0.72e-3 ]


#Change units to um
D = [D_*1e6 for D_ in D]
V = [V_*1e3 for V_ in V]
dt=0.01#1.0#

SD=[sqrt(D_*dt*2.0) for D_ in D]

VVV=[dt*(1-sigma_)*V_ for sigma_, V_ in zip(sigma, V)]

# %% [markdown]
# Container jest sztucznym tworem, który ma zapewnić stałe stężenie na granicy endothelium.

# %% [markdown]
# Inicjalizacja CUDY

# %%
cuda.init()
device = cuda.Device(2)
ctx = device.make_context()
print device.name(), device.compute_capability(),device.total_memory()/1024.**3,"GB"
print "a tak wogóle to mamy tu:",cuda.Device.count(), " urządzenia"
# Out:
# Tesla C2050 (2, 0) 2.99969482422 GB
# a tak wogóle to mamy tu: 3  urządzenia

# %% [markdown]
# Definiujemy kernel:

# %%
def get_kernel(pars):

    rng_src = """
#define PI 3.14159265358979f

extern int printf(__const char *__restrict __format, ...);
/*
 * Return a uniformly distributed random number from the
 * [0;1] range.
 */
__device__ float rng_uni(unsigned int *state)
{
	unsigned int x = *state;

	x = x ^ (x >> 13);
	x = x ^ (x << 17);
	x = x ^ (x >> 5);

	*state = x;

	return x / 4294967296.0f;
}
/*
 * Generate two normal variates given two uniform variates. Przeksztalcenie Boxa-Mullera:
 */
__device__ void bm_trans(float& u1, float& u2)
{
	float r = sqrtf(-2.0f * logf(u1));
	float phi = 2.0f * PI * u2;
	u1 = r * cosf(phi);
	u2 = r * sinf(phi);
}


"""
    
    src = """

__device__  float D(float x, float y)
{{
    if(x<{L[0]}f)
    {{
        return {D[0]}f;
    }}
    else if (x<{L[0]}f+{L[1]}f){{
        return {D[1]}f;
    }}
    else if (x<{L[0]}f+{L[1]}f+{L[2]}f){{
        return {D[2]}f;
    }}
    else if (x<{L[0]}f+{L[1]}f+{L[2]}f+{L[3]}f){{
        return {D[3]}f;
    }}
    else
    {{
        return {D[4]}f;
    }}
}}
__device__  float velsigma(float x, float y)
{{

    if (x<{L[0]}f+{L[1]}f){{
        return {vel0}f+(({velm}f)*copysignf(1, y));//*copysignf(1, y) ;
    }}
    else if (x<{L[0]}f+{L[1]}f+{L[2]}f){{
       return ({vvel0}f+({vvelm}f)*copysignf(1, y))*(1-{s[2]}f)*{dt}f ;//copysignf(1, y)
    }}
    else if (x<{L[0]}f+{L[1]}f+{L[2]}f+{L[3]}f){{
       return ({vvel0}f+({vvelm}f)*copysignf(1, y))*(1-{s[3]}f)*{dt}f ;//*copysignf(1, y)
    }}
    else
    {{
        return ({vvel0}f+({vvelm}f*copysignf(1, y)))*(1-{s[4]}f)*{dt}f ;//*copysignf(1, y)
    }}
}}




  

  
__device__  float k_react(float x, float y)
{{
    if (x>{L[0]}f+{L[1]}f+{L[2]}f+{L[3]}f)
    {{
      return {k_react[4]}f;
    }}
    else
    {{
      return -1.0;
    }}
}}
  
    
    
__global__ void advance_tex(float *x_i, float *y_i,int *indexes,unsigned int *rng_state,int sps)    
{{
    int idx = blockDim.x*blockIdx.x + threadIdx.x;
    float x, x1, y, y1;                                     //x1 to delta Y z publikacji
    int k;       
    float n1, n2, n3,c1; 	                             //do losowania
    unsigned int lrng_state;                         //liczby losowe
     
    for (k=0;k<sps;k++){{
        x = x_i[idx];
        y = y_i[idx];
        lrng_state = rng_state[idx];
        if(x>-1.0)
        {{
            //Reakcja lub pochlanianie
            c1 = rng_uni(&lrng_state);
            if(c1<=k_react(x,y)*{dt}f|| x>=({L[0]}f+{L[1]}f+{L[2]}f+{L[3]}f+{L[4]}f))
            {{
                x = -1.0;
            }}
            if(x>-1.0)
            {{
                //Dyfuzja
                n1 = rng_uni(&lrng_state);
		        n2 = rng_uni(&lrng_state);
		        n3 = rng_uni(&lrng_state);
		        bm_trans(n1, n2);         //rozklad normalny
                y1=y + D(x,y)* n2 ;
                x1 =fabsf( x + D(x,y) * n1);
                if (x1>=({L[0]}f+{L[1]}f+{L[2]}f+{L[3]}f+{L[4]}f))                    //dla x1 rowniez nalezy zastosowac warunek brzegowy
                {{
                    x=-1.0;
                }}
                else
                {{
                    x = fabsf(x + D(x1,y) * n1 + velsigma(x, y));
                }}
                if (x<={L[0]}f||x>({L[0]}f+{L[1]}f+{L[2]}f+{L[3]}f+{L[4]}f))
                {{
                    x=-1.0;                                                          /* //(1)  oproznienie kontenera i warunek brzegowy dla x 
                                                                                      //gdy tracer po dyfuzji nadal znajduje sie w kontenerze 
                                                                                      //lub sietam pojawil, zostaje deaktywowany, aby zapewnic
                                                                                      //pusty obszar dla generacji tracerow 
                                                                                      //wowczas nie ma koniecznosci liczenia ile tracerow 
                                                                                      //znajduje sie w zadanym obszarze i ile nalezaloby uzupelnic, 
                                                                                      z gory znana jest liczba trecerow do aktywacji   */   
                }}
                if (y1>{limit_up}f)
                {{
                    y1 = 2*{limit_up}f-y1;
                }}  
                else if (y1<{limit_down}f)
                {{
                    y1=2*({limit_down}f)-y1;
                }}
            }}
            x_i[idx] = x;
            y_i[idx]=y1;
            
        }}
        
        
        if (x==-1)
        {{
            indexes[idx+({distance}-1)-(idx%{distance})]=idx;                          //w tym polu znajduje sie indeks komorki tablicy w ktorej jest -1
                                                                                     //nie wazne ktoremu watkowi uda sie zapisac jako ostatniemu, wazne jest by bylo tam -1
                                                                                     //zamiast szukac zagladamy do tej wartosci w tabeli i mamy id niezywej czastki
                                                                                     //moze da sie to zrobic jeszcze inaczej
        }}
        __syncthreads();   
    
        if(idx%{distance}=={distance}-1)
        {{
            int iddd=indexes[idx];
            x_i[iddd]=rng_uni(&lrng_state)*{L[0]}f;
            y_i[iddd]=rng_uni(&lrng_state)*(fabsf({limit_down}f)+fabsf({limit_up}f))+({limit_down}f);
            indexes[idx]=-1;
        }}
             
        __syncthreads(); 
        rng_state[idx] = lrng_state;
    }}
}}
""".format(**pars)
    mod = SourceModule(rng_src+src,options=["--use_fast_math"]  )
    print src
    advance_tex = mod.get_function("advance_tex")
    return mod,advance_tex

# %%
def prepare():
    Rcell = 15e-3 # mm
    area=.64 # mm^2
    A = np.pi*Rcell**2/area
    
    w=14.3*1e-6
    r_m = 11e-6
    a = r_m/w
    
    sigma_lj = 1-(1-3/2.*a**2+0.5*a**3)*(1-1/3.*a**2)
    B=1-sigma_lj
    
    Kend_70mmHg = 3.22e-21
    phi_0=5e-4
    Klj=(w**2/3.)*(4.*w*phi_0)/Rcell * (1e-6)
    C = Kend_70mmHg - Klj
    
    d = (w**2/3.)*(4.*w)/Rcell * (1e-6)
    #print C
    
    mmHg2Pa = 133.3
    E = mmHg2Pa*70.0
    
    mu1=mu[1:]
    K1=K[1:]
    L1=L[2:]
    Ss = [L_*mu_/K_ for L_,K_,mu_ in zip(L1,K1,mu1)]
    F=sum(Ss)
    
    G = (L[0]+L[1])*mu[0]
    
    
    return A,a , B, C,d, E, F, G

# %%
def klj(y):
    Rcell = 15e-3 # mm
    area=.64 # mm^2
    A = np.pi*Rcell**2/area
    
    w=14.3*1e-6
    
    
    d = (w**2/3.)*(4.*w)/Rcell * (1e-6)
    
    Wmax = 50
    Wmin = 0.17
    srodek = (Wmax+Wmin)/2
    szerokosc = srodek - Wmin
    print srodek, szerokosc
    WSS=srodek+szerokosc*np.sign(y)
    
   # WSS=10.0-9.9*exp(-y*y/(2*5*5));
    SI = 0.38*exp(-0.79*WSS) + 0.225*exp(-0.043*WSS);
    MC = 0.003797* exp(14.75*SI); 
    LC = 0.307 + 0.805 * MC ;
    phi = LC*A;
    return d *phi;

# %%
def VV(y):
    
    Rcell = 15e-3 # mm
    w=14.3*1e-6
    Kend_70mmHg = 3.22e-21
    phi_0=5e-4
    Klj=(w**2/3.)*(4.*w*phi_0)/Rcell * (1e-6)
    C = Kend_70mmHg - Klj
    mu1=mu[1:]
    K1=K[1:]
    L1=L[2:]
    Ss = [L_*mu_/K_ for L_,K_,mu_ in zip(L1,K1,mu1)]
    F=sum(Ss)
    
    G = (L[0]+L[1])*mu[0]
    Kend = C+klj(y);
    RW0 = G/(Kend*1e6);
    RWC = RW0+F;
    
    mmHg2Pa = 133.3
    E = mmHg2Pa*70.0
    return E/RWC*1e6;

# %%
def sig(y):
    w=14.3*1e-6
    r_m = 11e-6
    a = r_m/w
    Rcell = 15e-3 # mm
    sigma_lj = 1-(1-3/2.*a**2+0.5*a**3)*(1-1/3.*a**2)
    b=1-sigma_lj
    Kend_70mmHg = 3.22e-21
    phi_0=5e-4
    Klj=(w**2/3.)*(4.*w*phi_0)/Rcell * (1e-6)
    c = Kend_70mmHg - Klj
    return 1-(b*klj(y))/(c+klj(y));

# %%
print VV(0)
# Out:
# 25.085 24.915
# 0.0176717035189

# %% [markdown]
# ### Inicjalizacja kerneli i przygotowanie symulacji

# %%
Nsteps = 1024*40
blocks =50000      #ilosc blokow odpowiada ilosci tracerow w obszarze o stalym stezeniu, a kazdym bloku symulowany jest zawsze 1 tracer z tego obszaru.(2)
                   #w kazdym watku jest zagwarantowane (1) ze po kazdym kroku symulacji kontener jest oprozniony
block_size = 512   #dobrany aby calkowita ilosc tracerow w ciagu calej symulacji byla odpowiednia


n_tracers = blocks*block_size   #polowa to martwe dusze

xinit = np.ones(n_tracers,dtype=np.float32)
xinit = xinit * (-1)
yinit = np.ones(n_tracers,dtype=np.float32)
#polozenie -1 znaczy, ze dany watek nie jest jeszcze wykorzystywany w symulacji, ale jest gotowy do wykorzystania,
#dzieki temu symulacja nie musi byc sterowana w nadzednym watku, aby kazdorazowo zmieniac ilosc tracerow i odpowiadajacych im watkow
distance=block_size/2
ainit =-1* np.ones(n_tracers, dtype=np.int32)
for i in range(0, n_tracers, distance):
    xinit[i] = (L[0]) * np.random.random_sample()
    yinit[i] = -3.0+6.0*np.random.random_sample()
#Z pliku
#xinit = np.ones(n_tracers,dtype=np.float32)
#binit= np.genfromtxt("testx_5norm18",dtype=np.float32)
#xinit=xinit*binit
#yinit = np.ones(n_tracers,dtype=np.float32)
#binit= np.genfromtxt("testy_5norm18",dtype=np.float32)
#yinit=yinit*binit
print D
tracers= ((0 < xinit) & (xinit <= L[0])).sum()
print "  tracers" , tracers


lmax = 3.0
lmin=-3.0
#parametry do skoku
smin = sig(lmin)
smax = sig(lmax)
s0=(smin+smax)/2#srodek
sm = s0-smin#szerokosc
vmin=VV(lmin)
vmax = VV(lmax)
v0=(vmin+vmax)/2#srodek    velocity 
vm = v0-vmin#szerokosc
print v0, vm, s0, sm
#print V
vvmin=(1-smin)*vmin*dt
vvmax=(1-smax)*vmax*dt
vv0=(vvmin+vvmax)/2#srodek    velocity*(1-sigma)*dt
vvm = vv0-vvmin#szerokosc
print vv0, vvm
pars = {'dt':dt, 'L':L, 'D':SD, 's':sigma, 'k_react':k_react, 'V':VVV, 'distance':distance,  'limit_up':lmax, 'limit_down':lmin,  'vel0':vv0, 'velm':vvm, 'vvel0':v0, 'vvelm':vm}
mod,advance = get_kernel(pars)



dx_i = gpuarray.to_gpu (xinit)
dy_i = gpuarray.to_gpu (yinit)
rng_state = np.array(np.random.randint(1,2147483648,size=n_tracers),dtype=np.uint32)
rng_state_g = gpuarray.to_gpu(rng_state)
da_i = gpuarray.to_gpu (ainit)
print n_tracers,Nsteps,n_tracers*Nsteps/1e9,"G","dt=",dt
# Out:
# [6e-05, 6e-05, 5.4, 0.00318, 0.049999999999999996]
#   tracers
#  100000
# 25.085 24.915
# 25.085 24.915
# 25.085 24.915
# 25.085 24.915
# 25.085 24.915
# 25.085 24.915
# 0.0242908526032 -0.00662591733313 0.926018104834 0.0663049533229
# 2.23641445027e-05 -2.10080176954e-05
#
#
# __device__  float D(float x, float y)
# {
#     if(x<0.2f)
#     {
#         return 0.00109544511501f;
#     }
#     else if (x<0.2f+1.8f){
#         return 0.00109544511501f;
#     }
#     else if (x<0.2f+1.8f+10.0f){
#         return 0.328633534503f;
#     }
#     else if (x<0.2f+1.8f+10.0f+2.0f){
#         return 0.00797496081495f;
#     }
#     else
#     {
#         return 0.0316227766017f;
#     }
# }
# __device__  float velsigma(float x, float y)
# {
#
#     if (x<0.2f+1.8f){
#         return 2.23641445027e-05f+((-2.10080176954e-05f)*copysignf(1, y));//*copysignf(1, y) ;
#     }
#     else if (x<0.2f+1.8f+10.0f){
#        return (0.0242908526032f+(-0.00662591733313f)*copysignf(1, y))*(1-0.8272f)*0.01f ;//copysignf(1, y)
#     }
#     else if (x<0.2f+1.8f+10.0f+2.0f){
#        return (0.0242908526032f+(-0.00662591733313f)*copysignf(1, y))*(1-0.9827f)*0.01f ;//*copysignf(1, y)
#     }
#     else
#     {
#         return (0.0242908526032f+(-0.00662591733313f*copysignf(1, y)))*(1-0.8836f)*0.01f ;//*copysignf(1, y)
#     }
# }
#
#
#
#
#
#
#
# __device__  float k_react(float x, float y)
# {
#     if (x>0.2f+1.8f+10.0f+2.0f)
#     {
#       return 0.00014f;
#     }
#     else
#     {
#       return -1.0;
#     }
# }
#
#
#
# __global__ void advance_tex(float *x_i, float *y_i,int *indexes,unsigned int *rng_state,int sps)
# {
#     int idx = blockDim.x*blockIdx.x + threadIdx.x;
#     float x, x1, y, y1;                                     //x1 to delta Y z publikacji
#     int k;
#     float n1, n2, n3,c1; 	                             //do losowania
#     unsigned int lrng_state;                         //liczby losowe
#
#     for (k=0;k<sps;k++){
#         x = x_i[idx];
#         y = y_i[idx];
#         lrng_state = rng_state[idx];
#         if(x>-1.0)
#         {
#             //Reakcja lub pochlanianie
#             c1 = rng_uni(&lrng_state);
#             if(c1<=k_react(x,y)*0.01f|| x>=(0.2f+1.8f+10.0f+2.0f+200.0f))
#             {
#                 x = -1.0;
#             }
#             if(x>-1.0)
#             {
#                 //Dyfuzja
#                 n1 = rng_uni(&lrng_state);
# 		        n2 = rng_uni(&lrng_state);
# 		        n3 = rng_uni(&lrng_state);
# 		        bm_trans(n1, n2);         //rozklad normalny
#                 y1=y + D(x,y)* n2 ;
#                 x1 =fabsf( x + D(x,y) * n1);
#                 if (x1>=(0.2f+1.8f+10.0f+2.0f+200.0f))                    //dla x1 rowniez nalezy zastosowac warunek brzegowy
#                 {
#                     x=-1.0;
#                 }
#                 else
#                 {
#                     x = fabsf(x + D(x1,y) * n1 + velsigma(x, y));
#                 }
#                 if (x<=0.2f||x>(0.2f+1.8f+10.0f+2.0f+200.0f))
#                 {
#                     x=-1.0;                                                          /* //(1)  oproznienie kontenera i warunek brzegowy dla x
#                                                                                       //gdy tracer po dyfuzji nadal znajduje sie w kontenerze
#                                                                                       //lub sietam pojawil, zostaje deaktywowany, aby zapewnic
#                                                                                       //pusty obszar dla generacji tracerow
#                                                                                       //wowczas nie ma koniecznosci liczenia ile tracerow
#                                                                                       //znajduje sie w zadanym obszarze i ile nalezaloby uzupelnic,
#                                                                                       z gory znana jest liczba trecerow do aktywacji   */
#                 }
#                 if (y1>3.0f)
#                 {
#                     y1 = 2*3.0f-y1;
#                 }
#                 else if (y1<-3.0f)
#                 {
#                     y1=2*(-3.0f)-y1;
#                 }
#             }
#             x_i[idx] = x;
#             y_i[idx]=y1;
#
#         }
#
#
#         if (x==-1)
#         {
#             indexes[idx+(256-1)-(idx%256)]=idx;                          //w tym polu znajduje sie indeks komorki tablicy w ktorej jest -1
#                                                                                      //nie wazne ktoremu watkowi uda sie zapisac jako ostatniemu, wazne jest by bylo tam -1
#                                                                                      //zamiast szukac zagladamy do tej wartosci w tabeli i mamy id niezywej czastki
#                                                                                      //moze da sie to zrobic jeszcze inaczej
#         }
#         __syncthreads();
#
#         if(idx%256==256-1)
#         {
#             int iddd=indexes[idx];
#             x_i[iddd]=rng_uni(&lrng_state)*0.2f;
#             y_i[iddd]=rng_uni(&lrng_state)*(fabsf(-3.0f)+fabsf(3.0f))+(-3.0f);
#             indexes[idx]=-1;
#         }
#
#         __syncthreads();
#         rng_state[idx] = lrng_state;
#     }
# }
# 25600000
#  40960 1048.576 G dt= 0.01
# -c:182: UserWarning: The CUDA compiler suceeded, but said the following:
# kernel.cu(99): warning: variable "n3" was set but never used
#
# kernel.cu(99): warning: variable "n3" was set but never used

# %% [markdown]
# Uruchomienie symulacji
# -----------------------
# Co x kroków kontrola koncentracji w kontenerze

# %%
import time
test = np.int32(0)
sps = np.int32(100000)#2000000 950000
size = np.int32(n_tracers)
                          
start = time.time()
for k in range(100):
    filex = "skok_testx_bbminus"+str(k)
    filey="skok_testy_bbminus"+str(k)
    x_file = "skok_x_bbminus"+str(k)+".jpg"
    y_file = "skok_y_bbminus"+str(k)+".jpg"
    hist_file = "skok_hist_bbminus"+str(k)+".jpg"
    advance(dx_i,dy_i,da_i,rng_state_g, sps, block=(block_size,1,1), grid=(blocks,1))
    ctx.synchronize()
    print filex
    print ((0 < dx_i.get()) & (dx_i.get() <= L[0])).sum()
    x=dx_i.get()
    y=dy_i.get()
    y=y[x>-1.0]
    x=x[x>-1.0]
    if k%1==0:
        with open(filex, 'w') as f:
            f.writelines(str(j)  + '\n' for j in x)
        with open(filey, 'w') as f:
            f.writelines(str(j)  + '\n' for j in y)
    clf()
 #   xx=[]
 #   c=[]
 #   j=0.1
 #   print x.max()
 #  while j< x.max()+0.2:
  #      a= ((j-0.1 <x) & (x <= j+0.1)).sum()
 #       c.append(a/10000.)
 #       xx.append(j)
 #       j+=0.2
  #  figsize(24,6)
  #  d=[0]+np.cumsum(L).tolist()
 #   colors=['c','r','g','b','y']
 #  for j,(l1,l2) in enumerate(zip(d[:],d[1:])):
 #       plt.axvspan(l1,l2, facecolor=colors[j], alpha=0.2)
  #  plt.grid(True,axis='y', which='major')
  #  plot(xx,c, 'ro')
  #  savefig(x_file)
  #  clf()
    
    yy=[]
    c=[]
    j=-5.1
    print y.max()
    while j< y.max()+0.2:
        a= ((j-0.1 <y) & (y <= j+0.1)).sum()
        c.append(a/50000.)
        yy.append(j)
        j+=0.2
    figsize(24,6)
    plt.grid(True,axis='y', which='major')
    plot(yy,c, 'ro')
    savefig(y_file)
    clf()
    
#    H,xx,yy=np.histogram2d(x,y, bins=(1000,1000)) 
  #  extent =[ yy[0], yy[-1],xx[-1], 0.0]
  #  figsize(50,50)
  #  imshow(H, extent=extent)

  #  savefig(hist_file)

elapsed = (time.time() - start)  
print elapsed,np.nonzero(np.isnan(dx_i.get()))[0].shape[0]
# Out:
# skok_testx_bbminus0
# 100000
# 3.0
# skok_testx_bbminus1
# 100000
# 3.0
# skok_testx_bbminus2
# 100000
# 3.0
# skok_testx_bbminus3
# 100000
# 3.0
# skok_testx_bbminus4
# 100000
# 3.0

# %%
figsize(24,6)
clf()
#imshow(v[0]**2+v[1]**2,origin='top',alpha=0.2)

#plot(xinit,'r.')
plot(dx_i.get(),dy_i.get(),'.',markersize=8,color='k')
#axis([-0,2,-30,30])
print ((0 < xinit) & (xinit <= L[0])).sum()

# %%
data = np.genfromtxt("test3.log")
xh=data
xx=[]
c=[]
i=0.1
print xh.max()
while i< xh.max()+0.2:
    a= ((i-0.1 <xh) & (xh <= i+0.1)).sum()
    c.append(a/2622.)
    xx.append(i)
    i+=0.2
#print c
#print xx
figsize(24,6)

data2 = np.genfromtxt("test2.log")
xh2=data2#dx_i.get()
xx2=[]
c2=[]
i2=0.1
print xh2.max()
while i2< xh2.max()+0.2:
    a2= ((i2-0.1 <xh2) & (xh2 <= i2+0.12)).sum()
    c2.append(a2/(2622.))
    xx2.append(i2)
    i2+=0.2
    
    
d=[0]+np.cumsum(L).tolist()
colors=['c','r','g','b','y']
for i,(l1,l2) in enumerate(zip(d[:],d[1:])):
    plt.axvspan(l1,l2, facecolor=colors[i], alpha=0.2)
plt.grid(True,axis='y', which='major')
plot(xx,c, 'ro')

plot(xx2,c2, 'go')
#axis([0,25,0,1.5])
# Out:
# 126.971
# 213.475

# %%
data = np.genfromtxt("testx9")
xh=data#dx_i.get()
xx=[]
c=[]
i=0.1
print xh.max()
while i< xh.max()+0.2:
    a= ((i-0.1 <xh) & (xh <= i+0.1)).sum()
    c.append(a/10000)
    xx.append(i)
    i+=0.2
#print c
#print xx
figsize(24,6)


d=[0]+np.cumsum(L).tolist()
colors=['c','r','g','b','y']
for i,(l1,l2) in enumerate(zip(d[:],d[1:])):
    plt.axvspan(l1,l2, facecolor=colors[i], alpha=0.2)
plt.grid(True,axis='y', which='major')
plot(xx,c, 'ro')


#axis([-1.5,1.5,0,6000])
# Out:
# 150.364

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b04e631a5d27> in <module>()
# ----> 1 xh=dx_i.get()
#       2 xx=[]
#       3 c=[]
#       4 i=0
#       5 while i< int(xh.max())+10:
#
# NameError: name 'dx_i' is not defined

# %% [markdown]
# zamknięcie CUDY

# %%
ctx.pop()
ctx.detach()

# %%
# Out:
# 98172
# 99
# 132

# %%
# Out:
# 99
# 99

# %%
# Out:
# [437, 419, 424, 440, 465, 437, 465, 461, 433, 466, 410, 435, 441, 400, 451, 455, 439, 419, 464, 399, 435, 458, 458, 450, 443, 448, 458, 438, 426, 422, 458, 440, 424, 466, 427, 432, 476, 458, 432, 443, 421, 450, 450, 432, 424, 425, 421, 430, 460, 429, 411, 426, 452, 430, 389, 420, 452, 413, 460, 415, 400, 455, 427, 443, 449, 430, 423, 467, 419, 451, 427, 434, 399, 434, 442, 407, 417, 411, 438, 447, 431, 462, 459, 430, 446, 426, 432, 428, 468, 450, 454, 391, 410, 454, 439, 433, 491, 408, 452, 433, 437, 435, 465, 371, 457, 479, 434, 439, 422, 458, 464, 479, 399, 456, 464, 428, 422, 496, 423, 444, 420, 470, 405, 421, 456, 470, 459, 457, 425, 438, 430, 420, 383, 447, 448, 425, 427, 449, 440, 438, 464, 446, 433, 424, 447, 422, 425, 457, 400, 429, 404, 444, 436, 420, 421, 440, 464, 434, 435, 439, 429, 426, 414, 468, 482, 436, 392, 438, 486, 434, 405, 443, 428, 425, 408, 430, 433, 427, 437, 441, 416, 468, 470, 455, 455, 455, 449, 436, 446, 413, 421, 404, 423, 431, 428, 447, 429, 453, 422, 414, 2]

# %%
data = np.genfromtxt("test2.log")
#xh=dx_i.get()
xh=data
xx=[]
c=[]
i=0.1
while i< xh.max()+0.2:
    a= ((i-0.1 <xh) & (xh <= i+0.1)).sum()
    c.append(a/2622.)
    xx.append(i)
    i+=0.2
#print c
#print xx
figsize(24,6)


d=[0]+np.cumsum(L).tolist()
colors=['c','r','g','b','y']
for i,(l1,l2) in enumerate(zip(d[:],d[1:])):
    plt.axvspan(l1,l2, facecolor=colors[i], alpha=0.2)
plt.grid(True,axis='y', which='major')
plot(xx,c, 'ro')

# %%
#x,y = dx_i.get(),dy_i.get()
x, y = np.genfromtxt("testx9"),np.genfromtxt("testy9")
x=x[x>-1.0]
y=y[x>-1.0]
H,xx,yy=np.histogram2d(x,y)#,bins=(1000,100)) 
extent =[ yy[0], yy[-1],xx[-1], 0.0]

# %%
figsize(50,30)
imshow(H, extent=extent)
savefig("test.jpg")

# %%
figsize?

# %%
savefig?
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full',)).History will not be written to the database.
